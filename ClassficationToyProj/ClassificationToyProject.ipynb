# %% [markdown]
# <img src="https://t4.ftcdn.net/jpg/03/62/48/17/360_F_362481762_WYOXzZBC8J63iIu26IeoxXlo7hhIa47w.jpg" alt="Description" width="100" height="100">
# <h1>ClassicationToyProject</h1>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('ClassificationToyProject/placement-dataset.csv')
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
#unwanted coloumn unamed -filter
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df=df.iloc[:,1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %% [markdown]
# #Steps
# #0.Preprocess*EDA*Feature Selection
# #1.Extract input and output cols
# #Scale the cols
# #Train test split
# #Train the model
# #Evaluate the model/model selection
# #Deploy the model

# %%
df.info()   #Step0
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt  #EDA

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
#Step1
x=df.iloc[:,0:2]
x.shape
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y=df.iloc[:,-1]
y.shape
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
# !pip install sklearn

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1) #inp,out,fraction of data to hide

# %%
x_train
# Out:
#     cgpa     iq
# 77   7.3   50.0
# 84   5.7  169.0
# 80   4.9  196.0
# 22   4.9  120.0
# 94   4.7   52.0
# ..   ...    ...
# 67   5.0  118.0
# 96   4.4   42.0
# 95   4.3  200.0
# 86   5.1  128.0
# 51   4.8  141.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 77    1
# 84    0
# 80    0
# 22    0
# 94    0
#      ..
# 67    0
# 96    0
# 95    0
# 86    0
# 51    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 42   7.6   89.0
# 29   7.0  112.0
# 58   8.0   79.0
# 64   7.0   64.0
# 56   6.1   65.0
# 3    7.4  132.0
# 21   7.1  151.0
# 76   4.9  155.0
# 87   5.7  132.0
# 16   5.2  224.0

# %%
y_test
# Out:
# 42    1
# 29    1
# 58    1
# 64    1
# 56    0
# 3     1
# 21    1
# 76    0
# 87    1
# 16    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[ 1.21638536e+00, -1.90442788e+00],
#        [-1.97331281e-01,  1.16039896e+00],
#        [-9.04189601e-01,  1.85577984e+00],
#        [-9.04189601e-01, -1.01588565e-01],
#        [-1.08090418e+00, -1.85291819e+00],
#        [-6.39117731e-01, -3.59137038e-01],
#        [ 1.03967078e+00, -1.95593758e+00],
#        [ 2.27667284e+00, -1.01588565e-01],
#        [ 3.32812459e-01, -5.39420970e-01],
#        [-7.27475021e-01, -1.49235032e+00],
#        [-4.62403151e-01, -2.56117649e-01],
#        [-1.69940521e+00, -6.16685512e-01],
#        [-1.08090418e+00, -7.58337173e-02],
#        [-1.08973991e-01,  1.08313441e+00],
#        [-9.04189601e-01,  6.96811704e-01],
#        [ 9.51313489e-01,  1.93304438e+00],
#        [-5.50760441e-01, -7.58337173e-02],
#        [-8.15832311e-01, -8.48479139e-01],
#        [ 7.74598909e-01, -3.07627344e-01],
#        [-9.04189601e-01, -1.62112456e+00],
#        [ 8.62956199e-01,  3.87753535e-01],
#        [-1.08973991e-01,  4.65018078e-01],
# ...

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 1.48145723, -0.89998883],
#        [ 0.95131349, -0.30762734],
#        [ 1.83488639, -1.15753731],
#        [ 0.95131349, -1.54386002],
#        [ 0.15609788, -1.51810517],
#        [ 1.30474265,  0.2074696 ],
#        [ 1.03967078,  0.6968117 ],
#        [-0.9041896 ,  0.79983109],
#        [-0.19733128,  0.2074696 ],
#        [-0.63911773,  2.57691556]])

# %%
#Train the model
#We have decided to use Logistic Regression so import that
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
#Train the object clf of LogisticRegression
clf.fit(x_train,y_train)
clf
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
#accuracy=80%

# %%
#What is the decision boundary that our model has drawn , to see that we will use:
# !pip install mlxtend
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
#deploy if accuracy is good
#this lib convert python object to files for deploying
#everything in python is an object
import pickle

# %%
pickle.dump(clf,open("model.pkl","wb"))
